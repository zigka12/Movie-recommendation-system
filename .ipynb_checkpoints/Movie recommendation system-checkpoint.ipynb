# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
movies_df = pd.read_csv(r"C:\Users\Aryan Sangam\Downloads\Movie recommendation system\Datasets\tmdb_5000_movies.csv")
credits_df = pd.read_csv(r"C:\Users\Aryan Sangam\Downloads\Movie recommendation system\Datasets\tmdb_5000_credits.csv")

# %%
movies_df = movies_df.merge(credits_df, left_on='title', right_on = 'title', how='left')
movies_df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...
